# %%
###############
### Imports ###
###############

from OLS_REGRESSION import *
from sklearn import datasets
import seaborn as sns
sns.set()

# %%
data = sns.load_dataset('tips')
CD = data.copy()
target = CD['total_bill']
CD = CD.drop('total_bill',axis=1)
CD = dummify(CD,drop=['sex','day','time'])

# %%
allchecks(CD,target)
# Out:
# No strong multicolinearity present
# (None, None)

# %%
perform_regression(CD,target,cov_type='HC2').summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             total_bill   R-squared:                       0.568
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     76.57
# Date:                Tue, 04 Jan 2022   Prob (F-statistic):           8.80e-35
# Time:                        09:06:13   Log-Likelihood:                -776.77
# No. Observations:                 244   AIC:                             1562.
# Df Residuals:                     240   BIC:                             1576.
# Df Model:                           3
# Covariance Type:                  HC2
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7790      1.360      2.043      0.041       0.113       5.445
# ...

# %%
partialplots(CD,target)
